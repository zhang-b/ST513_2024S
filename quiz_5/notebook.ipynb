# %% [markdown]
# # Attempt 1

# %%
from matplotlib import pyplot as plt
import numpy as np
from scipy import stats

# %% [markdown]
# ## Q1

# %%
1 - stats.norm.cdf(1.6)
# Out:
# 0.054799291699557995

# %% [markdown]
# ## Q8 ???

# %%
x = 0
x -= -5
x /= 3.1
stats.norm.cdf(x)
# Out:
# 0.9466172328659591

# %%
x = 0
rv = stats.norm(loc=-5, scale=3.1)
f = rv.cdf
rv.mean(), rv.std(), f(x)
# Out:
# (-5.0, 3.1, 0.9466172328659591)

# %% [markdown]
# ## Q10 ???

# %%
rv = stats.betaprime(a=9, b=14)
f = rv.pdf
x = np.linspace(0, 2, 500)
plt.figure(figsize=(12, 4))
plt.plot(x, f(x))
plt.grid(visible=True)
rv.median(), rv.mean()
# Out:
# (0.6342581579058596, 0.6923076923076923)

# %% [markdown]
# ## Q11 ???

# %%
rv = stats.betaprime(a=3, b=13)
f = rv.pdf
x = np.linspace(0, 1, 500)
plt.figure(figsize=(12, 4))
plt.plot(x, f(x))
plt.grid(visible=True)
rv.median(), rv.mean()
# Out:
# (0.21112394532309076, 0.25)

# %% [markdown]
# ## Q21

# %%
rv = stats.norm(loc=10, scale=2)
cdf = rv.cdf
cdf(10.2) - cdf(9.5)
# Out:
# 0.13853416295995258

# %% [markdown]
# ## Q24

# %%
cdf = stats.norm().cdf
cdf(2) - cdf(-2)
# Out:
# 0.9544997361036416

# %% [markdown]
# ## Q25

# %%
cdf = stats.norm(loc=100, scale=15).cdf
cdf(105) - cdf(101)
# Out:
# 0.10398219551787125
